# %%
# %load_ext autoreload
# %config Completer.use_jedi = False
# %autoreload 2
from preprocess import *
from sklearn.feature_extraction.text import TfidfVectorizer
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
base_df = pd.read_csv('aita_preprocessed_only_unedited.csv', sep='\t')
base_df
# Out:
#        Unnamed: 0      id     timestamp  \
# 0               0  1ytxov  1.393279e+09
# 1               2  1yu8hi  1.393285e+09
# 2               4  1yueqb  1.393288e+09
# 3               5  1yugsc  1.393289e+09
# 4               6  1yux10  1.393298e+09
# ...           ...     ...           ...
# 71874       97621  ex8ys3  1.580576e+09
# 71875       97622  ex8ywl  1.580576e+09
# 71876       97625  ex9dwo  1.580578e+09
# 71877       97626  ex9egs  1.580578e+09
# 71878       97627  ex9g78  1.580578e+09
#
#                                                    title  \
# 0      [AITA] I wrote an explanation in TIL and came ...
# 1            I told a goth girl she looked like a clown.
# 2      [AITA] I let my story get a little long and bo...
# 3      AITA Had a disagreement about Les Miserables w...
# 4            [ATIA] I permanently give a customer decaf.
# ...                                                  ...
# 71874                   AITA for yelling at my daughter?
# 71875    AITA for giving my brother my Air Force Ribbon?
# 71876  AITA for attempting to keep my students out of...
# 71877  WIBTA if I left my brothers fate up to the state?
# 71878  WIBTA for rocking the boat at work because my ...
#
#                                                     body          verdict  \
# 0      [AITA] I wrote an explanation in TIL and came ...          asshole
# 1      I told a goth girl she looked like a clown.I w...  not the asshole
# 2      [AITA] I let my story get a little long and bo...  not the asshole
# 3      AITA Had a disagreement about Les Miserables w...          asshole
# 4      [ATIA] I permanently give a customer decaf.His...   everyone sucks
# ...                                                  ...              ...
# 71874  AITA for yelling at my daughter?\nI(46,M) have...          asshole
# 71875  AITA for giving my brother my Air Force Ribbon...  not the asshole
# 71876  AITA for attempting to keep my students out of...  not the asshole
# 71877  WIBTA if I left my brothers fate up to the sta...  not the asshole
# 71878  WIBTA for rocking the boat at work because my ...  not the asshole
#
#        score  num_comments  is_asshole  \
# 0         52          13.0           1
# 1         74          15.0           0
# 2          6           4.0           0
# 3         22          15.0           1
# 4         12          14.0           1
# ...      ...           ...         ...
# 71874     67          54.0           1
# 71875      3          44.0           0
# 71876      4          15.0           0
# 71877    280         140.0           0
# 71878      5          21.0           0
#
#                                     processed_body_split  \
# 0      ['[', 'aita', ']', 'i', 'wrote', 'explanation'...
# 1      ['i', 'told', 'goth', 'girl', 'she', 'looked',...
# 2      ['[', 'aita', ']', 'i', 'let', 'my', 'story', ...
# 3      ['aita', 'disagreement', 'le', 'miserables', '...
# 4      ['[', 'atia', ']', 'i', 'permanently', 'give',...
# ...                                                  ...
# 71874  ['aita', 'yelling', 'my', 'daughter', '?', 'i'...
# 71875  ['aita', 'giving', 'my', 'brother', 'my', 'air...
# 71876  ['aita', 'attempting', 'keep', 'my', 'student'...
# 71877  ['wibta', 'i', 'left', 'my', 'brother', 'fate'...
# 71878  ['wibta', 'rocking', 'boat', 'work', 'my', 'me...
#
#                                           processed_body  num_words
# 0      [ aita ] i wrote explanation til came condesce...         68
# 1        i told goth girl she looked like clown.i four .         10
# 2      [ aita ] i let my story get little long boring...         17
# 3      aita disagreement le miserables coworker.i lov...        158
# 4      [ atia ] i permanently give customer decaf.his...         94
# ...                                                  ...        ...
# 71874  aita yelling my daughter ? i ( 46 , ) helping ...        162
# 71875  aita giving my brother my air force ribbon ? y...        394
# 71876  aita attempting keep my student adult matter ?...        249
# 71877  wibta i left my brother fate state ? little ba...        176
# 71878  wibta rocking boat work my mentor homophobic t...        300
#
# [71879 rows x 12 columns]

# %%
X = base_df.processed_body.values

# %%
unigram_vectorizer = TfidfVectorizer(ngram_range=(1,1), max_df=0.75, min_df=2)
bigram_vectorizer = TfidfVectorizer(ngram_range=(1,2), max_df=0.75, min_df=2)
trigram_vectorizer = TfidfVectorizer(ngram_range=(1,3), max_df=0.75, min_df=2)
X_uni = data=unigram_vectorizer.fit_transform(X)
X_bi = data=bigram_vectorizer.fit_transform(X)
X_tri = data=trigram_vectorizer.fit_transform(X)
